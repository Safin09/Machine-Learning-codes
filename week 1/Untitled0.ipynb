# %%
 print("hello world")
# Out:
# hello world

# %%
x = 24
if x>23:
  print(f"{x}greater then 23")
elif x==23:
  print(str(x)+"equal to 23")
else:
  print(x,"smaller then 23")
# Out:
# 24greater then 23

# %%
for i in range(5,10,2):
  print(i)
# Out:
# 5
# 7
# 9

# %%
num = 9
f=1
for i in range(1,num+1):
  f=f*i
print(f)
# Out:
# 24

# %%
import math as mt
print(mt.factorial(1000))
# Out:
# ...

# %%
l = [34,"two",32.09,[1,3,4]]
for i in range(4):
  print(l[i])
# Out:
# 34
# two
# 32.09
# [1, 3, 4]

# %%
for i in l:
  print(i)
# Out:
# 34
# two
# 32.09
# [1, 3, 4]
